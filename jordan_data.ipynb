# %%
import csv
import pandas as pd

# %%
df = pd.read_csv("combined.csv", encoding='latin-1')

# %%
df.head()
# Out:
#    Unnamed: 0                                         book.title  \
# 0           1            ÌÛ la recherche de l'essence du langage
# 1           2                            A study of glossematics
# 2           3  A study of writing the foundations of grammato...
# 3           4  An essay towards a real character and a philos...
# 4           5  Analyse et genÌ¬se : regards sur la thÌ©orie d...
#
#                                                   id  page page.location  \
# 0  https://derridas-margins.princeton.edu/referen...    62             e
# 1  https://derridas-margins.princeton.edu/referen...    83             f
# 2  https://derridas-margins.princeton.edu/referen...    13             b
# 3  https://derridas-margins.princeton.edu/referen...   108             e
# 4  https://derridas-margins.princeton.edu/referen...   317             d
#
#        type                                            book.id book.page  \
# ...

# %%
json = df.to_json(orient = "index")

# %%
dfJSON = df.to_json(path_or_buf= "jordans_json",orient='records')
# json.loads(dfJSON)

# %%
print(dfJSON)
# Out:
# None
